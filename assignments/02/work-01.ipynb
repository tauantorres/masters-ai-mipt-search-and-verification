# %% [markdown]
# Academic literature review(s): monograph, key article(s), conference sessions
# The objective is the analysis of the review of a monograph or key article (or several articles that address the same issue), a conference section in the academic field studied by the specific participant of the course.
#
# PARAMETERS
#
# Format: PowerPoint presentation.
#
# Number of slides: at least 10 (excluding the introductory and concluding slides).
#
# The content: you are asked to analyze the reviews in academic literature (or direct reviews during the selection stage, if available) in the context of their correlation with the real merits and shortcomings of the discussed monograph/article/several articles or the conference section that the course participant attended in person or studied via video (including responses from the author(s), if provided).
#
# Evaluation is based on a 10-point scale. The cutoff point is less than 3 out of 10 possible points. Weight of the evaluation: 25%.
#
# Evaluation Criteria:
#
# - Disclosure of the topic = degree of correlation between the reviews and the discussed text/presentations and responses of the authors - 40% of the total score; NB: on the first two slides, participants are requested to present the area of their own research, relating it to the chosen object of analysis;
#
# - Justification of the positions put forth by the author in response to the assignment - 40% of the total score;
#
# - Visual representativeness of the project - 10% of the total score;
#
# - Spelling, punctuation, and style - 10% of the total score.
#
# Important! In cases of academic misconduct by the student (focusing on plagiarism and data falsification), the score may be nullified.
#
# An additional advantage will be the use of research context in the argumentation (comparisons with other studies conducted in this field during the same time frame as the publication of the monograph/articles—5 to 7 years in either direction)—up to a 30% increase in the score.
#
# When rounding up to a specified decimal place, the next significant digit to the right of the targeted digit will be considered. If this digit is 5 or greater, the rounding up will be upwards.
#
# Number of authors on the project: Completion of the assignment is permitted by up to 4 authors. In this case, it is necessary to include a slide at the end of the presentation that indicates the significance of each author's contribution.
#
# Note 1: If it is not possible to find discussions in video, audio, or written representation, this part of the analysis may be omitted; it is acceptable to study the case by referencing or using ideas from other authors.
#
# Note 2: In the case of analyzing reviews of texts presented in other languages, the assignment must invariably be presented in English.
#
# Note 3: Reviews can be found on publishing house websites, journal pages, as well as through conversations with colleagues, and also based on personal participation in projects.
#
# Note 4: If reviews are absent in the public domain, please focus on tracing the reception of the author's ideas in other publications and sources. Consequently, the criterion for the significance of the discussed text is the presence of an acceptable level of citation within the relevant field of study, which has already been partially mentioned.
#
# NB: to be completed by the deadline (see further). An extension may be granted upon submission of an official medical certificate regarding illness or by providing a similar document regarding participation in a project that significantly contributes to the MIPT brand, of which I should be informed no later than one week.
#
# Please account for the possibility of connectivity issues when uploading responses to the LMS, and it is advisable to upload the file at least 10 minutes before the deadline.
#
# Good luck to all of you again!

# %% [markdown]
# Perfect — this is a **literature review analysis project**, and you’re being asked to:
#
# > ✅ choose a **monograph, key article(s), or conference session**,<br>
# > ✅ **analyze how it was reviewed** (by other scholars or participants),<br>
# > ✅ **connect it to your own research area**,<br>
# > ✅ and **critically assess** whether those reviews match the real merits or flaws of the work.<br>
#
# Let’s break down how to start this **step-by-step** 👇
#
# ---
#
# ## 🧭 Step 1 — Choose your topic and object of analysis
#
# You need to pick **one** of these:
#
# * 📘 **A monograph** (a single-author academic book or detailed study on one topic),
# * 📄 **A key article or group of related articles** on the same issue,
# * 🎤 **A conference session** (either one you attended or a recorded one you can access online).
#
# ➡️ The choice should **relate to your own research field**.
#
#
# ---
#
# ## 🧩 Step 2 — Find the academic **reviews or reception**
#
# Once you pick the work, your goal is to **analyze its academic reception** — i.e. how scholars discussed or reviewed it.
#
# You can find these:
#
# * In **Google Scholar** → search `"review of [book title]"` or look at **cited by** references.
# * On the **publisher’s website** (e.g. MIT Press, Cambridge University Press).
# * In **academic journals** like *AI & Society*, *Journal of AI Research*, *Ethics and Information Technology*, etc.
# * In **conference proceedings**, or even YouTube if you pick a conference talk.
#
# If there are **no explicit reviews**, you can analyze **how the author’s ideas were cited or received** in later publications.
#
# ---
#
# ## 📊 Step 3 — Plan your PowerPoint (structure)
#
# Here’s a simple structure that matches the grading criteria:
#
# | Slide | Content                                 | Notes                                                           |
# | ----- | --------------------------------------- | --------------------------------------------------------------- |
# | 1     | **Title + Authors**                     | Project title, your name, course name                           |
# | 2     | **Your Research Area**                  | Briefly explain your field and link it to the chosen work       |
# | 3     | **Object of Analysis**                  | Describe the monograph/article/session and its main thesis      |
# | 4     | **Reviews Overview**                    | Where the reviews came from, who wrote them                     |
# | 5–6   | **Positive Reviews (Main Merits)**      | Summarize and quote key praise points                           |
# | 7–8   | **Critical Reviews (Shortcomings)**     | Summarize critiques or controversial points                     |
# | 9     | **Your Critical Evaluation**            | Your judgment: Do you agree with the reviewers? Were they fair? |
# | 10    | **Comparative Context**                 | Mention other similar studies (±5–7 years around publication)   |
# | 11    | **Conclusions**                         | What this tells us about the topic and its relevance            |
# | 12    | **References / Sources**                | Full bibliographic list                                         |
# | +1    | *(If team project)* Contributions slide |                                                                 |
#
# ---
#
# ## 🧠 Step 4 — Analytical focus (what the professor wants)
#
# You must analyze **the correlation between reviews and the actual content**.
# That means:
#
# * Did reviewers understand the author correctly?
# * Were their criticisms justified or biased?
# * Did the author (if they responded) address them convincingly?
# * Does your own analysis align with or contradict those reviews?
#
# ---
#
# ## 🎨 Step 5 — Visuals & formatting
#
# * Use **figures, quotes, and timeline graphics** (conference sessions, citation trends).
# * Avoid text-heavy slides — keep bullets short.
# * Include **citations** on slides (APA or MLA).
#
# ---
#
# ## ✳️ Step 6 — Bonus points (up to +30%)
#
# To gain the “up to +30% increase”:
#
# * Compare your chosen work with **2–3 other publications from 5–7 years before/after**.
#
#   * Example: if reviewing a 2018 article, include works from 2011–2025.
#   * Show how the discussion evolved or how your chosen work influenced later research.
#
# ---
#
# ## 🧩 Step 7 — What to do next
#
# Let’s begin by deciding **what you’ll analyze**.
# Please tell me:
#
# 1. Your specific **field of research** (e.g. AI ethics, AI in law, political economy of AI, etc.), and
# 2. Whether you prefer to review a **book**, an **academic article**, or a **conference session**.
#
# Once you tell me that, I’ll:
#
# * suggest 2–3 concrete, high-quality works,
# * show where to find their reviews, and
# * give you a ready-to-use **PowerPoint outline** with slide-by-slide draft text.
#
# Would you like me to start by suggesting the works next?

# %% [markdown]
# ### Slides 05-06 — **Critical Reviews**
#
# **Slide 05**
# **Title:** Critical Reception & Oversights
# **Content:**
#
# * The article by Machine Learning for Fluid Mechanics (Brunton, Noack & Koumoutsakos, 2020) acknowledges its own limitations: e.g., “ML algorithms often come without guarantees for performance, robustness, or convergence” and “Incorporating and enforcing known flow physics is a challenge and opportunity for ML algorithms”. ([Scribd][1])
# * A subsequent review/perspective: Machine learning in fluid dynamics: A critical assessment (Taira, Rigas & Fukami, 2025) emphasises that although ML has out-performed traditional approaches in some cases, “many fluid mechanics problems remain beyond the reach of current machine-learning techniques.” ([link.aps.org][2])
# * The 2025 piece further highlights key challenges:
#
#   * Need for **community-maintained datasets** and **open-source code repositories** to accelerate progress. ([arXiv][3])
#   * The gap between excitement and the reality of applying ML in complex fluid-flow problems (e.g., high Reynolds-number turbulence, multiphase flows) remains significant.
# * **Critical point for your analysis:** Although Brunton et al. set out a forward-looking agenda, actual uptake and mature validation of many of their “emerging opportunities” remain partial. Use this gap as part of your evaluation.
#
# **Slide 06**
# **Title:** Specific Critical Points & Their Implications
# **Content:**
#
# * **Generalizability & interpretability**: ML methods in fluid mechanics are often “black-boxes”. Although Brunton et al. address interpretability (“When do methods succeed or fail?”) ([Scribd][1]), later assessments argue that interpretability remains a major barrier.
# * **Physics-integration challenges**: Brunton et al. call for hybrid models (data + first-principles) but leave many open-ended questions about how this will scale. The 2025 critique emphasises that the field is still in “critical transitional state”. ([link.aps.org][2])
# * **Reproducibility, dataset bias, industrial relevance**: The 2025 article calls out that many ML applications in fluids rely on curated, idealised datasets rather than “real-world” complex flows, and that open sharing remains limited.
# * **Implication for your research area**: For your interest in porous media & continuum mechanics + ML, these critiques matter: does Brunton et al.’s framework readily apply to highly non-linear porous media flows and deformation coupling (your background)? Probably not fully yet — you can highlight this gap.
# * **Suggested bullet for slide:** “The review’s ambition is broad; the follow-up literature shows that several of its identified ‘opportunities’ remain aspirational rather than fully realised.”
#
# ---
#
# ### Slides 07-08 — **Positive Reviews**
#
# **Slide 07**
# **Title:** Major Praises & Strengths
# **Content:**
#
# * Brunton et al.’s article has become a **widely-cited reference** in ML + fluid mechanics: Google Scholar cites show thousands of citations. ([scholar.google.com][4])
# * It is praised for **bringing clarity** to a rapidly evolving field: its lucid breakdown of ML methods (SVM, Random Forest, Neural Networks etc) and connection to fluid-mechanics tasks (reduced-order modelling, control) has been widely used. ([arXiv][5])
# * The article is appreciated for **setting an agenda**: the section “Future Issues” (e.g., interpretability, hybridization, open-science) has guided many subsequent research directions. ([Scribd][1])
# * From the 2023 survey A Review of Physics‑Informed Machine Learning in Fluid Mechanics (Sharma et al., 2023): It references Brunton et al. as foundational in the PIML (physics-informed ML) subfield, indicating the review’s influence. ([MDPI][6])
#
# **Slide 08**
# **Title:** Why It Works: Key Merits Linked to Your Context
# **Content:**
#
# * **Broad applicability**: The article covers modelling, control, optimisation — this breadth means it maps well onto many problems (including your porous-media + ML interest).
# * **Bridging communities**: The authors explicitly appeal to both fluid-mechanics researchers and ML/data scientists, helping foster interdisciplinary work — which fits your integration of continuum mechanics + AI.
# * **Visionary timing**: Published in 2020 (based on 2019 advance version) just before the major generative-AI boom, the article was ahead of the curve; your Slide 03 already highlights this.
# * **Framework for future work**: The “strengths & limitations” section, plus the “future issues”, mean the article is not just descriptive but normative — telling the field where to go. This makes it strong for your assignment because you can assess how those prescriptions have played out in 2023–25.
# * **Suggested bullet for slide:** “Its clarity and agenda-setting role make it an indispensable reference for anyone at the intersection of ML + fluid mechanics.”
#
# ---
#
# ### 🔗 Additional References for You to Explore
#
# Here are more works that either review ML + fluid mechanics broadly or provide critical/contrast perspective — useful for your “comparative context” and to deepen your “reviews” section.
#
# 1. Applying machine learning to study fluid mechanics (2021) – Springer. Discusses ML stages (problem formulation → data → architecture → loss → optimisation) and situates Brunton et al.’s work. ([SpringerLink][7])
# 2. A Review of Physics‑Informed Machine Learning in Fluid Mechanics (Sharma et al., 2023) – Covers the PIML subfield, cites Brunton et al.; useful for knowing how the field has evolved. ([MDPI][6])
# 3. Perspective on machine learning for advancing fluid mechanics (2019) – A pre-cursor perspective, gives background to Brunton et al.’s timing. ([link.aps.org][8])
# 4. Assessment of supervised machine learning methods for fluid flows (2020) – More focused on supervised ML for fluid flows, good for contrast. ([arXiv][9])
# 5. The new paradigm of computational fluid dynamics (2025) – Discusses how CFD + ML is becoming a new paradigm; good for your “future outlook” or conclusion slide. ([pubs.aip.org][10])
# 6. Machine Learning Reshaping Computational Fluid Dynamics (2025) – Highlights current breakthroughs (e.g., CNNs accelerating wind-field prediction) and can show how far the field has come since Brunton et al. ([MDPI][11])
#
# ---
#
# ### ✅ What to do now
#
# * Copy the draft texts above into your slides and adjust formatting/wording to your style.
# * From the additional references list, download at least 2 of the papers (say 2021 & 2023) and extract 1-2 quotes each about Brunton et al.’s contribution or critique.
# * For slides 07-08 (positive reviews) you might add bullet quotes like:
#
#   > “the article provides a powerful information-processing framework that can augment, and possibly even transform, current lines of fluid-mechanics research” (Brunton et al., 2020) ([Annual Reviews][12])
# * For slides 05-06 (critical reviews) you might add bullet quotes like:
#
#   > “many fluid mechanics problems remain beyond the reach of current machine-learning techniques” (Taira et al., 2025) ([link.aps.org][2])
# * On Slide 10 (“Comparative Context”), you can include the 2019 perspective (Slide 3 above) and the 2023/2025 reviews to show the ±5-7 year window around Brunton et al.
#
# ---
#
# If you like, I can generate **full slide text drafts for all your slides** (Slides 1-12) ready-to-copy into PowerPoint (including indicators for visuals). Would you like that?
#
# [1]: https://www.scribd.com/document/522671390/annurev-fluid-010719-060214?utm_source=chatgpt.com "Machine Learning For Fluid Mechanics | PDF - Scribd"
# [2]: https://link.aps.org/doi/10.1103/8t52-mtb9?utm_source=chatgpt.com "Machine learning in fluid dynamics: A critical assessment"
# [3]: https://arxiv.org/abs/2508.13430?utm_source=chatgpt.com "A critical assessment of machine learning in fluid dynamics"
# [4]: https://scholar.google.com/citations?hl=en&user=TjzWdigAAAAJ&utm_source=chatgpt.com "‪Steven L. Brunton‬ - ‪Google Scholar‬"
# [5]: https://arxiv.org/abs/1905.11075?utm_source=chatgpt.com "[1905.11075] Machine Learning for Fluid Mechanics - arXiv"
# [6]: https://www.mdpi.com/1996-1073/16/5/2343?utm_source=chatgpt.com "A Review of Physics-Informed Machine Learning in Fluid Mechanics"
# [7]: https://link.springer.com/article/10.1007/s10409-021-01143-6?utm_source=chatgpt.com "Applying machine learning to study fluid mechanics"
# [8]: https://link.aps.org/doi/10.1103/PhysRevFluids.4.100501?utm_source=chatgpt.com "Perspective on machine learning for advancing fluid mechanics"
# [9]: https://arxiv.org/abs/2001.09618?utm_source=chatgpt.com "Assessment of supervised machine learning methods for fluid flows"
# [10]: https://pubs.aip.org/aip/pof/article/37/8/081302/3357757/The-new-paradigm-of-computational-fluid-dynamics?utm_source=chatgpt.com "The new paradigm of computational fluid dynamics"
# [11]: https://www.mdpi.com/2311-5521/10/10/275?utm_source=chatgpt.com "Machine Learning Reshaping Computational Fluid Dynamics"
# [12]: https://www.annualreviews.org/doi/10.1146/annurev-fluid-010719-060214?utm_source=chatgpt.com "Machine Learning for Fluid Mechanics - Annual Reviews"

# %% [raw]
# Slide 01:
#
# Title:
# Machine Learning for Fluid Mechanics
# Steven L. Brunton, Bernd R. Noack, and Petros Koumoutsakos
#
# Names:
# Mudassar Ullah and Tauan Torres
#
# Course:
# Masters in AI - MIPT - Search and Verification

# %% [raw]
# Slide 02:
#
# Tauan Torres
#
# During my Bachelor's degree, I focused in study Continuum Mechanics,
# specifically the Filtration of Fluids through Porous Elastic Media.
# This topic in specific, requires a deep understanding of Fluid Mechanics principles, but
# also Solid Mechanics. The cominations of these two fields and on top of that, adding
# the complexity of Porous Media, makes it a very challenging topic, since the models
# are not straight forward, meaning, non-linear models easy to solve. During my work at the lab,
# we can try and conduct several experiments, and collected so many data, but yet, solving problems
# such as change of porosity due to deformation of the media, or non-linear flow regimes, are still
# very challenging to be modeled using traditional methods, and quite complicated numerical simulations.
#
# After finishing my Bachelor's degree, I started to work with Machine Learning and AI, and I could see
# that many of the problems we faced in the lab, could be solved using these techniques. My passion for Continuum Mechanics
# and Fluid Mechanics never faded away, and because of that I decided to persue this Masters in AI to learn as much as can
# and perhaps combine both beatiful fields to solve complex problems.
#
# In my free time, I enjoy researching about others scientists that work in the field of Fluid Mechanics,
# and while back I found articles, courses and even books that discuss the use of Machine Learning in Fluid Mechanics.
# One of these books is "Data-Driven Fluid Mechanics. Combining First Principles and Machine Learning" by Steven L. Brunton.
# Ever since, I've been following his work and research.
#
#
# Mudassar Ullah

# %% [raw]
# Slide 03:
#
# Objective of Analysis
#
# In 2019, Steven L. Brunton, Bernd R. Noack, and Petros Koumoutsakos published
# an article called "Machine Learning for Fluid Mechanics" in the Annual Review of Fluid Mechanics.
# In their own words right from the abstract:
# "The field of fluid mechanics is rapidly advancing, driven by unprecedented
# volumes of data from experiments, field measurements, and large-scale simulations at multiple spatiotemporal scales.
# Machine learning (ML) offers a wealth of techniques to extract information from data that can be translated into knowledge about the underlying fluid mechanics.
# Moreover, ML algorithms can augment domain knowledge and automate tasks related to flow control and optimization.
# This article presents an overview of past history, current developments, and emerging opportunities of ML for fluid mechanics."
#
# It is a not surprise to anyone that nowadays, the search for Machine Learning applications, AI techniques, and Data-Driven methods
# are the new trend in almost every scientific field. Fluid Mechanics is no exception.
# But the interesting part about that, is that this article was published in 2019,
# which was before the big boom of AI in 2023, when ChatGPT and generative AI models started to be
# widely known by the public, and yet, the authors could already see the potential of these techniques
# to be applied in the field of Fluid Mechanics, and from that moment to now, how far has the field advanced and
# enbraced these new techniques.

# %% [raw]
# Slide 04:
#
# Reviews and Receptions
# Where the reviews came from, who wrote them
#
# The article presents a broad review of how Machine Learning interfaces
# with Fluid Mechanics, covering modeling, control, data-driven techniques,
# and highlighting both opportunities, challenges, strengths and limitations.
# In the moment that we are writing this analysis, the article has 3289 citations
# according to Google Scholar, which is a very high number for an article published in 2019/2020, and
# we found a very few reviews criticizing the article, instead, most of the reviews praise this work, and
# consider it a landmark in the field of Machine Learning for Fluid Mechanics, highlighting it as the go-to reference
# for a "new era" of research in this field, where from now on, the combination of traditional methods with
# data-driven techniques will be the standard/start approach to solve/modeling complex problems in Fluid Mechanics.
#
# That said, we brought two articles that review and discuss this work, not specifically criticizing it, but
# bringing some points that were mentioned in the article that could be further discussed or analyzed.
#
# 1. It is cited in a newer “critical assessment” article:
# Machine learning in fluid dynamics: A critical assessment
# by Kunihiko Taira et al. (2025) which explicitly references
# Brunton et al.’s paper [https://journals.aps.org/prfluids/abstract/10.1103/8t52-mtb9?utm_source=chatgpt.com]
#
# 2. It is also referenced in other review articles of the field (for example, on physics-informed ML)
# which treat it as a foundational/seminal piece. [https://www.mdpi.com/1996-1073/16/5/2343?utm_source=chatgpt.com]

# %% [raw]
# Slides 05-06:
#
# Critical Reviews
# Summarize critiques or controversial points
# [https://journals.aps.org/prfluids/abstract/10.1103/8t52-mtb9?utm_source=chatgpt.com]
#
# This article called "Machine learning in fluid dynamics: A critical assessment" by Kunihiko Taira et al. was very
# recently published in September 16, 2025.
# Already in the abstract, the authors acknowledge the increasing role of Machine Learning in Fluid Dynamics,
# and in their own words:
# "The fluid dynamics community has increasingly adopted machine learning to analyze, model, predict, and control a wide range of flows...
# In some cases, machine learning has even outperformed traditional approaches. However, many fluid mechanics problems remain beyond the reach of current machine learning techniques...
# This perspective article aims to spark discussions and encourage collaborative efforts to advance the integration of machine learning in fluid dynamics."
#
# In this last part, they highlight one of the 'future issues' already mentioned in Brunton et al.'s article, more specifically the points 5 and 6:
# "
# 5. Machine learning encourages open sharing of data and software. Can this assist the
# development of frameworks for reproducible and open science in fluid mechanics?
# 6. Fluids researchers will benefit from interfacing with the machine learning community, where the latest advances are reported in peer reviewed conferences.
# "
# [image 01]

# %% [markdown]
# ### Slides 05-06 — **Critical Reviews**
#
# **Slide 05**
# **Title:** Critical Reception & Oversights
# **Content:**
#
# * The article by Machine Learning for Fluid Mechanics (Brunton, Noack & Koumoutsakos, 2020) acknowledges its own limitations: e.g., “ML algorithms often come without guarantees for performance, robustness, or convergence” and “Incorporating and enforcing known flow physics is a challenge and opportunity for ML algorithms”. ([Scribd][1])
# * A subsequent review/perspective: Machine learning in fluid dynamics: A critical assessment (Taira, Rigas & Fukami, 2025) emphasises that although ML has out-performed traditional approaches in some cases, “many fluid mechanics problems remain beyond the reach of current machine-learning techniques.” ([link.aps.org][2])
# * The 2025 piece further highlights key challenges:
#
#   * Need for **community-maintained datasets** and **open-source code repositories** to accelerate progress. ([arXiv][3])
#   * The gap between excitement and the reality of applying ML in complex fluid-flow problems (e.g., high Reynolds-number turbulence, multiphase flows) remains significant.
# * **Critical point for your analysis:** Although Brunton et al. set out a forward-looking agenda, actual uptake and mature validation of many of their “emerging opportunities” remain partial. Use this gap as part of your evaluation.
#
# **Slide 06**
# **Title:** Specific Critical Points & Their Implications
# **Content:**
#
# * **Generalizability & interpretability**: ML methods in fluid mechanics are often “black-boxes”. Although Brunton et al. address interpretability (“When do methods succeed or fail?”) ([Scribd][1]), later assessments argue that interpretability remains a major barrier.
# * **Physics-integration challenges**: Brunton et al. call for hybrid models (data + first-principles) but leave many open-ended questions about how this will scale. The 2025 critique emphasises that the field is still in “critical transitional state”. ([link.aps.org][2])
# * **Reproducibility, dataset bias, industrial relevance**: The 2025 article calls out that many ML applications in fluids rely on curated, idealised datasets rather than “real-world” complex flows, and that open sharing remains limited.
# * **Implication for your research area**: For your interest in porous media & continuum mechanics + ML, these critiques matter: does Brunton et al.’s framework readily apply to highly non-linear porous media flows and deformation coupling (your background)? Probably not fully yet — you can highlight this gap.
# * **Suggested bullet for slide:** “The review’s ambition is broad; the follow-up literature shows that several of its identified ‘opportunities’ remain aspirational rather than fully realised.”

# %% [raw]
# Slides 07-08:
#
# Positeve Reviews
# Summarize and quote key praise points

# %% [markdown]
# Slide 07
#
# - Brunton et al.’s article has become a **widely-cited reference** in ML + fluid mechanics: Google Scholar cites show thousands of citations. ([https://scholar.google.com/citations?hl=en&user=TjzWdigAAAAJ&view_op=list_works&sortby=pubdate][4])
# - It is praised for **bringing clarity** to a rapidly evolving field: its lucid breakdown of ML methods (SVM, Random Forest, Neural Networks etc) and connection to fluid-mechanics tasks (reduced-order modelling, control) has been widely used.
# - The article is appreciated for **setting an agenda**: the section “Future Issues” (e.g., interpretability, hybridization, open-science) has guided many subsequent research directions.
# - From the 2023 survey A Review of Physics‑Informed Machine Learning in Fluid Mechanics (Sharma et al., 2023): It references Brunton et al. as foundational in the PIML (physics-informed ML) subfield, indicating the review’s influence.
#
# Slide 08
#
# - Broad applicability: The article covers modelling, control, optimisation — this breadth means it maps well onto many problems (including your porous-media + ML interest).
# - Bridging communities: The authors explicitly appeal to both fluid-mechanics researchers and ML/data scientists, helping foster interdisciplinary work — which fits your integration of continuum mechanics + AI.
# - Visionary timing: Published in 2020 (based on 2019 advance version) just before the major generative-AI boom, the article was ahead of the curve; your Slide 03 already highlights this.
# - Framework for future work: The “strengths & limitations” section, plus the “future issues”, mean the article is not just descriptive but normative — telling the field where to go. This makes it strong for your assignment because you can assess how those prescriptions have played out in 2023–25.
# - Suggested bullet for slide: “Its clarity and agenda-setting role make it an indispensable reference for anyone at the intersection of ML + fluid mechanics.”

# %% [raw]
# Slide 09:
#
# Our Critical Review
# Your judgment: Do you agree with the reviewers? Were they fair?
#
#
# We agree with the reviewers that the article by Brunton et al.
# is a seminal and foundational work in the field of Machine Learning for Fluid Mechanics.
#
# In fact, since its publication in 2019, it has been widely cited and referenced in numerous subsequent studies, reviews, and surveys.
# The article has played a crucial role in shaping the research landscape,
# highlighting key opportunities and challenges, and inspiring further investigations in this interdisciplinary area.
# Moreover, the sense of open science and collaboration that the authors promote is essential
# for the advancement of this field, and we believe that the fluid mechanics community
# will greatly benefit from embracing these principles.

# %% [raw]
# Slide 10:
#
# Comparative Context
# Mention other similar studies (±5–7 years around publication)

# %% [raw]
# Slide 11:
#
# Conclusions
# What this tells us about the topic and its relevance
#
# All the topics under AI scope are growing fast, therefore the
# fields of Machine Learning and Deep Learning are no exception.
# It is very exiting to see that the Field of Fluid Mechanics is embracing these new techniques
# and trying to apply them to solve complex problems, which were not possible to be solved
# using traditional methods.
# The article by Brunton et al. is a landmark in this field, and it will be
# referenced for years to come as the starting point of a new era in Fluid Mechanics research,
# where data-driven techniques and AI methods will be standard tools in the researcher's toolbox.

# %% [raw]
# Slide 12:
#
# References
#
# https://arxiv.org/pdf/1905.11075
#
# https://faculty.washington.edu/sbrunton/ARFM2020.pdf?utm_source=chatgpt.com
#
# https://journals.aps.org/prfluids/abstract/10.1103/8t52-mtb9?utm_source=chatgpt.com
#
# https://www.mdpi.com/1996-1073/16/5/2343?utm_source=chatgpt.com
#
# https://link.springer.com/article/10.1007/s10409-021-01143-6?utm_source=chatgpt.com

# %% [raw]
# Slide 01:
#
# Title:
# Machine Learning for Fluid Mechanics
# Steven L. Brunton, Bernd R. Noack, and Petros Koumoutsakos
#
# Names:
# Mudassar Ullah and Tauan Torres
#
# Course:
# Masters in AI - MIPT - Search and Verification
#
#
# ---
#
# Slide 02:
#
# Tauan Torres
#
# During my Bachelor's degree, I focused in study Continuum Mechanics,
# specifically the Filtration of Fluids through Porous Elastic Media.
# This topic in specific, requires a deep understanding of Fluid Mechanics principles, but
# also Solid Mechanics. The cominations of these two fields and on top of that, adding
# the complexity of Porous Media, makes it a very challenging topic, since the models
# are not straight forward, meaning, non-linear models easy to solve. During my work at the lab,
# we can try and conduct several experiments, and collected so many data, but yet, solving problems
# such as change of porosity due to deformation of the media, or non-linear flow regimes, are still
# very challenging to be modeled using traditional methods, and quite complicated numerical simulations.
#
# After finishing my Bachelor's degree, I started to work with Machine Learning and AI, and I could see
# that many of the problems we faced in the lab, could be solved using these techniques. My passion for Continuum Mechanics
# and Fluid Mechanics never faded away, and because of that I decided to persue this Masters in AI to learn as much as can
# and perhaps combine both beatiful fields to solve complex problems.
#
# In my free time, I enjoy researching about others scientists that work in the field of Fluid Mechanics,
# and while back I found articles, courses and even books that discuss the use of Machine Learning in Fluid Mechanics.
# One of these books is "Data-Driven Fluid Mechanics. Combining First Principles and Machine Learning" by Steven L. Brunton.
# Ever since, I've been following his work and research.
#
#
# Mudassar Ullah
#
# ---
#
# Slide 03:
#
# Objective of Analysis
#
# In 2019, Steven L. Brunton, Bernd R. Noack, and Petros Koumoutsakos published
# an article called "Machine Learning for Fluid Mechanics" in the Annual Review of Fluid Mechanics.
# In their own words right from the abstract:
# "The field of fluid mechanics is rapidly advancing, driven by unprecedented
# volumes of data from experiments, field measurements, and large-scale simulations at multiple spatiotemporal scales.
# Machine learning (ML) offers a wealth of techniques to extract information from data that can be translated into knowledge about the underlying fluid mechanics.
# Moreover, ML algorithms can augment domain knowledge and automate tasks related to flow control and optimization.
# This article presents an overview of past history, current developments, and emerging opportunities of ML for fluid mechanics."
#
# It is a not surprise to anyone that nowadays, the search for Machine Learning applications, AI techniques, and Data-Driven methods
# are the new trend in almost every scientific field. Fluid Mechanics is no exception.
# But the interesting part about that, is that this article was published in 2019,
# which was before the big boom of AI in 2023, when ChatGPT and generative AI models started to be
# widely known by the public, and yet, the authors could already see the potential of these techniques
# to be applied in the field of Fluid Mechanics, and from that moment to now, how far has the field advanced and
# enbraced these new techniques.
#
#
# ---
#
# Slide 04:
#
# Reviews and Receptions
# Where the reviews came from, who wrote them
#
# The article presents a broad review of how Machine Learning interfaces
# with Fluid Mechanics, covering modeling, control, data-driven techniques,
# and highlighting both opportunities, challenges, strengths and limitations.
# In the moment that we are writing this analysis, the article has 3289 citations
# according to Google Scholar, which is a very high number for an article published in 2019/2020, and
# we found a very few reviews criticizing the article, instead, most of the reviews praise this work, and
# consider it a landmark in the field of Machine Learning for Fluid Mechanics, highlighting it as the go-to reference
# for a "new era" of research in this field, where from now on, the combination of traditional methods with
# data-driven techniques will be the standard/start approach to solve/modeling complex problems in Fluid Mechanics.
#
# That said, we brought two articles that review and discuss this work, not specifically criticizing it, but
# bringing some points that were mentioned in the article that could be further discussed or analyzed.
#
# 1. It is cited in a newer “critical assessment” article:
# Machine learning in fluid dynamics: A critical assessment
# by Kunihiko Taira et al. (2025) which explicitly references
# Brunton et al.’s paper [https://journals.aps.org/prfluids/abstract/10.1103/8t52-mtb9?utm_source=chatgpt.com]
#
# 2. It is also referenced in other review articles of the field (for example, on physics-informed ML)
# which treat it as a foundational/seminal piece. [https://www.mdpi.com/1996-1073/16/5/2343?utm_source=chatgpt.com]
#
#
# ---
#
# Slides 05-06:
# Critical Reviews
#
#
# - The article by Machine Learning for Fluid Mechanics (Brunton, Noack & Koumoutsakos, 2020) acknowledges its own limitations: e.g., “ML algorithms often come without guarantees for performance, robustness, or convergence” and “Incorporating and enforcing known flow physics is a challenge and opportunity for ML algorithms”. ([Scribd][1])
# - A subsequent review/perspective: Machine learning in fluid dynamics: A critical assessment (Taira, Rigas & Fukami, 2025) emphasises that although ML has out-performed traditional approaches in some cases, “many fluid mechanics problems remain beyond the reach of current machine-learning techniques.” ([link.aps.org][2])
# - The 2025 piece further highlights key challenges:
#   * Need for **community-maintained datasets** and **open-source code repositories** to accelerate progress. ([arXiv][3])
#   * The gap between excitement and the reality of applying ML in complex fluid-flow problems (e.g., high Reynolds-number turbulence, multiphase flows) remains significant.
# - Critical point for your analysis: Although Brunton et al. set out a forward-looking agenda, actual uptake and mature validation of many of their “emerging opportunities” remain partial. Use this gap as part of your evaluation.
#
# Slide 06
#
# - Generalizability & interpretability**: ML methods in fluid mechanics are often “black-boxes”. Although Brunton et al. address interpretability (“When do methods succeed or fail?”) ([Scribd][1]), later assessments argue that interpretability remains a major barrier.
# - Physics-integration challenges: Brunton et al. call for hybrid models (data + first-principles) but leave many open-ended questions about how this will scale. The 2025 critique emphasises that the field is still in “critical transitional state”. ([link.aps.org][2])
# - Reproducibility, dataset bias, industrial relevance**: The 2025 article calls out that many ML applications in fluids rely on curated, idealised datasets rather than “real-world” complex flows, and that open sharing remains limited.
#
#
# ---
#
# Slide 07
#
# - Brunton et al.’s article has become a **widely-cited reference** in ML + fluid mechanics: Google Scholar cites show thousands of citations. ([https://scholar.google.com/citations?hl=en&user=TjzWdigAAAAJ&view_op=list_works&sortby=pubdate][4])
# - It is praised for **bringing clarity** to a rapidly evolving field: its lucid breakdown of ML methods (SVM, Random Forest, Neural Networks etc) and connection to fluid-mechanics tasks (reduced-order modelling, control) has been widely used.
# - The article is appreciated for **setting an agenda**: the section “Future Issues” (e.g., interpretability, hybridization, open-science) has guided many subsequent research directions.
# - From the 2023 survey A Review of Physics‑Informed Machine Learning in Fluid Mechanics (Sharma et al., 2023): It references Brunton et al. as foundational in the PIML (physics-informed ML) subfield, indicating the review’s influence.
#
# Slide 08
#
# - Broad applicability: The article covers modelling, control, optimisation — this breadth means it maps well onto many problems (including your porous-media + ML interest).
# - Bridging communities: The authors explicitly appeal to both fluid-mechanics researchers and ML/data scientists, helping foster interdisciplinary work — which fits your integration of continuum mechanics + AI.
# - Visionary timing: Published in 2020 (based on 2019 advance version) just before the major generative-AI boom, the article was ahead of the curve; your Slide 03 already highlights this.
# - Framework for future work: The “strengths & limitations” section, plus the “future issues”, mean the article is not just descriptive but normative — telling the field where to go. This makes it strong for your assignment because you can assess how those prescriptions have played out in 2023–25.
# - Suggested bullet for slide: “Its clarity and agenda-setting role make it an indispensable reference for anyone at the intersection of ML + fluid mechanics.”
#
# ---
#
# Slide 09:
#
# Our Critical Review
# Your judgment: Do you agree with the reviewers? Were they fair?
#
#
# We agree with the reviewers that the article by Brunton et al.
# is a seminal and foundational work in the field of Machine Learning for Fluid Mechanics.
#
# In fact, since its publication in 2019, it has been widely cited and referenced in numerous subsequent studies, reviews, and surveys.
# The article has played a crucial role in shaping the research landscape,
# highlighting key opportunities and challenges, and inspiring further investigations in this interdisciplinary area.
# Moreover, the sense of open science and collaboration that the authors promote is essential
# for the advancement of this field, and we believe that the fluid mechanics community
# will greatly benefit from embracing these principles.
#
# ---
#
# Slide 10:
#
# Slide 10: Comparative Context – Research Horizon ± 5-7 Years
#
# - Preceding works (≈2013-2018): Although not always labelled “machine-learning for fluid mechanics”, earlier reviews such as data-driven modelling of chaotic flows and reduced-order modelling set the scene for Brunton et al. Their 2020 article built on this foundation by bringing ML methods into fluid-mechanics tasks in an agenda-setting way.
# - Peer / contemporary reviews (≈2019-2021): For example, the “Special issue on machine learning and data-driven methods in fluid dynamics” (Brunton et al. edit, 2020) provided a collection of articles exploring supervised ML for fluid flows.
#
# Later works (≈2023-2025):
#     - Machine learning in fluid dynamics: A critical assessment (Taira, Rigas & Fukami, 2025) offers a maturity-check: many of Brunton et al.’s “future issues” remain active challenges.
#     - The new paradigm of computational fluid dynamics – Empowering computational fluid dynamics with machine learning (2025) underscores that ML + CFD is now seen as a new paradigm rather than just an emerging trend.
#     - Machine Learning in Fluid Dynamics—Physics‑Informed Neural Networks (PINNs) Using Sparse Data: A Review (2025) takes the discussion further into PINNs and sparse-data regimes, reflecting one of the limitations Brunton et al. flagged.
#
# ---
#
# Slide 11:
#
# Conclusions
# What this tells us about the topic and its relevance
#
# All the topics under AI scope are growing fast, therefore the
# fields of Machine Learning and Deep Learning are no exception.
# It is very exiting to see that the Field of Fluid Mechanics is embracing these new techniques
# and trying to apply them to solve complex problems, which were not possible to be solved
# using traditional methods.
# The article by Brunton et al. is a landmark in this field, and it will be
# referenced for years to come as the starting point of a new era in Fluid Mechanics research,
# where data-driven techniques and AI methods will be standard tools in the researcher's toolbox.
#
#
# ---
#
# Slide 12:
#
# References
#
# [1] Steven L. Brunton Google Scholar Profile: [https://scholar.google.com/citations?hl=en&user=TjzWdigAAAAJ&view_op=list_works&sortby=pubdate]
#
# [2] Machine learning for fluid mechanics, Steven L. Brunton, Bernd R. Noack, and Petros Koumoutsakos: [https://arxiv.org/pdf/1905.11075]
#
# [3] A Review of Fluid Mechanics Machine learning for fluid mechanics, Sharma, et al.: [https://www.mdpi.com/1996-1073/16/5/2343]
#
# [4] Machine learning in fluid dynamics: A critical assessment by Kunihiko Taira, et al. : [https://journals.aps.org/prfluids/abstract/10.1103/8t52-mtb9]
#
# [5] The new paradigm of computational fluid dynamics: Empowering computational fluid dynamics with machine learning, Sien Hu et al.: [https://pubs.aip.org/aip/pof/article-abstract/37/8/081302/3357757/The-new-paradigm-of-computational-fluid-dynamics]
#
# [6] Machine Learning Reshaping Computational Fluid Dynamics: A Paradigm Shift in Accuracy and Speed, Aly Mousaad Aly: [https://www.mdpi.com/2311-5521/10/10/275]
#
# [7] Special issue on machine learning and data-driven methods in fluid dynamics, Steven L. Brunton, Maziar S. Hemati and Kunihiki Taira: [https://link.springer.com/article/10.1007/s00162-020-00542-y]
#
# [8] Machine Learning in Fluid Dynamics—Physics-Informed Neural Networks (PINNs) Using Sparse Data: A Review, Mouhammad El Hassani et al.: [https://www.mdpi.com/2311-5521/10/9/226]
